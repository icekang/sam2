# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from visualize_SAM2_predictions import get_show_annoation_function, get_patients, get_prediction_output
from pathlib import Path

# Create the prompting strategy name
prompter_names = ["mask", "k_border_3", "k_consistent_point"]
strategy_name = "::".join(sorted(prompter_names))
EVERY_N = 16
fold = 0
prediction_output = get_prediction_output(
    fold, strategy_name, EVERY_N
)

update_animation, fig, ax = get_show_annoation_function(
    fold=fold,
    prediction_output=prediction_output,
    patient_idx=0,
    EVERY_N=EVERY_N,
)

update_animation(200)
# Out:
# (<matplotlib.image.AxesImage at 0x7f68b90f0e10>,
# ...
#  <matplotlib.image.AxesImage at 0x7f68b93f5550>)
