# %%
from visualize_SAM2_predictions import get_show_annoation_function, get_patients
from pathlib import Path

# Create the prompting strategy name
prompter_names = ["mask", "consistent_point"]
strategy_name = "::".join(sorted(prompter_names))
EVERY_N = 16
fold =0

prediction_output_name = "fold{}_{}_annotate_every_{}".format(
    fold, strategy_name, EVERY_N
)
prediction_output = Path(prediction_output_name)

update_animation, fig, ax = get_show_annoation_function(fold=fold, prediction_output=prediction_output, patient_idx=0, EVERY_N=EVERY_N)

# %%
update_animation(200)
fig

# %%
update_animation(201)
fig

# %%
update_animation(202)
fig

# %%
update_animation(203)
fig

# %%
# Create the prompting strategy name
prompter_names = ["mask", "random_point"]
strategy_name = "::".join(sorted(prompter_names))
EVERY_N = 16
fold =0

prediction_output_name = "fold{}_{}_annotate_every_{}".format(
    fold, strategy_name, EVERY_N
)
prediction_output = Path(prediction_output_name)

update_animation, fig, ax = get_show_annoation_function(fold=fold, prediction_output=prediction_output, patient_idx=0, EVERY_N=EVERY_N)

# %%
update_animation(200)
fig

# %%
update_animation(201)
fig

# %%
update_animation(202)
fig

# %%
update_animation(203)
fig
